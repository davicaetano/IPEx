# %%
#It's better run in a local machine
import random
import timeit
def quicksort(X,k):
    esquerda = []
    direita = []
    k = k
    for i in range(len(X)):        
        if X[i] < X[k-1]:
            esquerda.append(X[i])
        elif X[i] > X[k-1]:
            direita.append(X[i])
    a = len(esquerda) + 1
    if a == k:
        return X[k-1]
    elif a > k:
        return quicksort(esquerda,k)
    else:
        return quicksort(direita,k-a)


def func(X,k):
    for i in range(len(X)):
        quicksort(X[i],k[i]) #This is a O(n log(n)) operation

N = []
S1 = []
S2 = []
tempo = []
for i in range(10):
    n = 50 #The length of the array
    m = (i+1) * 50
    X = []
    k = []
    for j in range(n):
        X.append(random.sample(range(m*100),m))
        k.append(random.choice(range(m)))
    Time1 = timeit.Timer("func(X,k)","from __main__ import func,X,k")

    tempo.append(Time1.timeit(number=1))
    N.append(m)
    S1.append(N[i] * math.log(N[i],2)/tempo[i])
    S2.append(N[i]/tempo[i])
    print("N=" + str(N[i])+ ";   Time=" + str(tempo[i]) + ";   N log(N)/Time= " + str(S1[i]/S1[0])+ ";   N/Time= " + str(S2[i]/S2[0]))
# Out:
# N=50;   Time=0.00295950417939;   N log(N)/Time= 1.0;   N/Time= 1.0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-c84b3695be2b> in <module>()
#      37     Time1 = timeit.Timer("func(X,k)","from __main__ import func,X,k")
#      38
# ---> 39     tempo.append(Time1.timeit(number=1))
#      40     N.append(m)
#      41     S1.append(N[i] * math.log(N[i],2)/tempo[i])
#
# C:\Python27\lib\timeit.pyc in timeit(self, number)
#     193         gc.disable()
#     194         try:
# --> 195             timing = self.inner(it, self.timer)
#     196         finally:
#     197             if gcold:
#
# C:\Python27\lib\timeit.pyc in inner(_it, _timer)
#
# <ipython-input-10-c84b3695be2b> in func(X, k)
#      21 def func(X,k):
#      22     for i in range(len(X)):
# ---> 23         quicksort(X[i],k[i]) #This is a O(n log(n)) operation
#      24
#      25 N = []
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
# ...
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# <ipython-input-10-c84b3695be2b> in quicksort(X, k)
#      14         return X[k-1]
#      15     elif a > k:
# ---> 16         return quicksort(esquerda,k)
#      17     else:
#      18         return quicksort(direita,k-a)
#
# RuntimeError: maximum recursion depth exceeded
